# %%
import json
import random
import time
import socket
import os.path
from os import path
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
DISCOUNT_RATE = 0.99
LEARNING_RATE = 0.01
BATCH_SIZE = 500
REPLAY_MEMORY_CAPACITY = 20000
TARGET_UPDATE_STEP = 1000
MAX_STEPS_PER_EPISODE = 5000
TOTAL_EPISODES = 10000
POLICY_NETWORK_SAVE_FILE = "./DrMarioDQN_final/policy_network"

# %%
loss_function = keras.losses.MeanSquaredError()
optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)

# %%
class Communicator:
    """Provides a socket communication between the DQN and Dr.Mario"""
    DR_MARIO_HOST = '192.168.0.107'
    PORT = 42012
    BUFFER_SIZE = 1024
    __connection = None
    
    def __init__(self):
        self.__connection = socket.socket(socket.AF_INET, socket.SOCK_STREAM) 

    def connect(self):
        self.__connection.connect((self.DR_MARIO_HOST, self.PORT))

    def read_state(self):
        state_str = self.__connection.recv(self.BUFFER_SIZE).decode()
        return state_str

    def send_action(self, action):
        self.__connection.sendall(str.encode(action))

    def __del__(self):
        self.__connection.close()

# %%
class State:
    board = None
    __position = None
    condition = None
    NUM_ROWS = 8
    NUM_COLS = 8
    STATE_SIZE = NUM_ROWS * NUM_COLS + 2
    TILE_TYPE_ENCODING = {
        "E": 0,
        "RV": 1, "YV": 2, "BV": 3,
        "RPL": 4, "RPR": 5, "RPU": 6, "RPD": 7, "RPN": 8,
        "YPL": 9, "YPR": 10, "YPU": 11, "YPD": 12, "YPN": 13,
        "BPL": 14, "BPR": 15, "BPU": 16, "BPD": 17, "BPN": 18,
    }

    def __init__(self, board, position, condition):
        self.board = board
        self.__position = position
        self.condition = condition
    
    def encodeState(self):
        encoded_state = self._encodeBoard()
        encoded_state.append(self.__position['row'])
        encoded_state.append(self.__position['col'])
        return encoded_state

    def _encodeBoard(self):
        encoded_board = []
        for row in self.board:
            for tile in row:
                encoded_board.append(self.TILE_TYPE_ENCODING[tile])
        
        return encoded_board

# %%
class Experience:
    state = None
    action = None
    reward = None
    next_state = None
    
    def __init__(self, state, action, reward, next_state):
        self.state = state
        self.action = action
        self.reward = reward
        self.next_state = next_state

# %%
class RewardManager:
    @staticmethod
    def getReward(state, next_state):
        if RewardManager.hasPlayerWon(next_state):
            return 100
        if RewardManager.hasPlayerLost(next_state):
            return -50

        state_viruses = RewardManager.__countViruses(state)
        next_state_viruses = RewardManager.__countViruses(next_state)

        reward = -1
        reward += RewardManager.getNumberNonEmptyTiles(state)
        reward -= RewardManager.getNumberNonEmptyTiles(next_state)
        reward += (state_viruses - next_state_viruses) * 10
        
        return reward

    @staticmethod
    def hasPlayerWon(state):
        return state.condition == "W"

    @staticmethod 
    def hasPlayerLost(state):
        return state.condition == "L"

    @staticmethod
    def getNumberNonEmptyTiles(state):
        number_non_empty_tiles = 0

        for row in state.board:
            for tile in row:
                if tile != "E":
                   number_non_empty_tiles += 1

        return number_non_empty_tiles

    @staticmethod
    def __countViruses(state):
        count = 0
        for row in state.board:
            for tile in row:
                if len(tile) == 2:
                    count += 1
        return count

# %%
class Environment:
    RESET_ACTION = "RS"
    QUIT_ACTION = "QT"
    PLAYER_ACTIONS = ["ML", "MR", "RL", "RR", "WT"]
    __communicator = None
    __current_state = None

    def __init__(self):
        self.__communicator = Communicator()
        self.__communicator.connect()
        self.reset()

    def reset(self):
        self.__communicator.send_action(self.RESET_ACTION)
        self.__current_state = self.__getState()
        return self.getCurrentState().encodeState()
        
    def getCurrentState(self):
        return self.__current_state

    def quit(self):
        self.__communicator.send_action(self.QUIT_ACTION)
    
    def makeAction(self, action):
        state = self.__current_state

        self.__communicator.send_action(self.PLAYER_ACTIONS[action])
        next_state = self.__getState()

        reward = RewardManager.getReward(self.__current_state, next_state)

        self.__current_state = next_state
        return Experience(state.encodeState(), action, reward, next_state.encodeState())

    def hasGameEnded(self):
        return self.__current_state.condition != "O"

    def __getState(self):
        state_str = self.__communicator.read_state()
        state_json = json.loads(state_str)
        return State(state_json["board"], state_json["position"], state_json["condition"])

# %%
class ReplayMemory:
    memory = []
    __capacity = 0
    __position_to_add = 0

    def __init__(self, capacity):
        self.__capacity = capacity

    def add(self, experience):
        if not(self.__isFull()):
            self.memory.append(experience)
        else:
            self.memory[self.__position_to_add] = experience
            self.__position_to_add = (self.__position_to_add + 1) % self.__capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def canProvideBatch(self, batch_size):
        return len(self.memory) >= batch_size
    
    def __isFull(self):
        return len(self.memory) == self.__capacity

# %%
def create_model():
    inputs = layers.Input(shape=(State.STATE_SIZE,))

    layer1 = layers.Dense(256, activation="relu")(inputs)
    layer2 = layers.Dense(128, activation="relu")(layer1)
    action = layers.Dense(len(Environment.PLAYER_ACTIONS), activation="linear")(layer2)

    return keras.Model(inputs=inputs, outputs=action)

# %%
class Agent:
    EPSILON_MIN = 0.01
    EPSILON_MAX = 1.0
    EPSILON_DECAY_RATE = 0.0025

    epsilon = None
    
    actions_count = 0
    model = None
    target_model = None

    def __init__(self, actions_count):
        self.actions_count = actions_count
        self.model = create_model()
        if path.exists(POLICY_NETWORK_SAVE_FILE + ".index"):
            self.model.load_weights(POLICY_NETWORK_SAVE_FILE)
        self.target_model = create_model()
        self.updateTargetModel()
        self.epsilon = self.EPSILON_MAX

    def updateTargetModel(self):
        self.target_model.set_weights(self.model.get_weights())
    
    def __explore(self):
        return random.randrange(self.actions_count)

    def __exploit(self, state):
        state_tensor = tf.convert_to_tensor(state)
        state_tensor = tf.expand_dims(state_tensor, 0)
        action_probs = self.model(state_tensor, training=False)
        action = tf.argmax(action_probs[0]).numpy()
        return action

    def chooseAction(self, state):
        if random.random() > self.epsilon:
            return self.__exploit(state)
        else:
            return self.__explore()

    def decayEpsilon(self, episode):
        self.epsilon = self.EPSILON_MIN + (self.EPSILON_MAX - self.EPSILON_MIN) * np.exp(-episode * self.EPSILON_DECAY_RATE)

# %%
def disassembleBatch(experiences):
    states = []
    actions = []
    rewards = []
    next_states = []

    for experience in experiences:
        states.append(experience.state)
        actions.append(experience.action)
        rewards.append(experience.reward)
        next_states.append(experience.next_state)

    return (np.array(states), np.array(actions), np.array(rewards), np.array(next_states))

# %%
episodes_rewards = []
memory = ReplayMemory(REPLAY_MEMORY_CAPACITY)

# %%
env = Environment()
agent = Agent(len(env.PLAYER_ACTIONS))
learning_steps = 0

# %%
number_steps_made = 0

for episode in range(0, TOTAL_EPISODES):
    agent.model.save_weights(POLICY_NETWORK_SAVE_FILE)
    state = env.reset()
    episode_reward = 0
    number_steps_made_in_episode = 0

    print(f'episode number: {episode}')
    print(f'episodes rewards: {episodes_rewards}')
    
    for step in range(0, MAX_STEPS_PER_EPISODE):
        number_steps_made += 1
        number_steps_made_in_episode += 1
        action = agent.chooseAction(state)
        experience = env.makeAction(action)
        memory.add(experience)
        state = experience.next_state
        episode_reward += experience.reward

        if memory.canProvideBatch(BATCH_SIZE):
            learning_steps += 1
            batch = memory.sample(BATCH_SIZE)
            states, actions, rewards, next_states = disassembleBatch(batch)

            opt_q_next_state = agent.target_model.predict(next_states)
            expected_opt_q = rewards + DISCOUNT_RATE * tf.reduce_max(
                opt_q_next_state, axis=1
            )
            masks = tf.one_hot(actions, agent.actions_count)

            with tf.GradientTape() as tape:
                q_values = agent.model(states)
                q_for_action = tf.reduce_sum(tf.multiply(q_values, masks), axis=1)
                loss = loss_function(expected_opt_q, q_for_action)

            # Backpropagation
            grads = tape.gradient(loss, agent.model.trainable_variables)
            optimizer.apply_gradients(zip(grads, agent.model.trainable_variables))

        if (learning_steps != 0) and (learning_steps % TARGET_UPDATE_STEP == 0):
            agent.updateTargetModel()

        if env.hasGameEnded():
            break
    
    print(f'number steps made: {number_steps_made}')
    print(f'number steps made in episode: {number_steps_made_in_episode}')
    print(f'epsilon: {agent.epsilon}')
    print()
    agent.decayEpsilon(episode)
    episodes_rewards.append(episode_reward)

print(episodes_rewards)
env.quit()
# Out:
# episode number: 0
# episodes rewards: []
# number steps made: 225
# number steps made in episode: 225
# epsilon: 1.0
#
# episode number: 1
# episodes rewards: [-296]
# number steps made: 510
# number steps made in episode: 285
# epsilon: 1.0
#
# episode number: 2
# episodes rewards: [-296, -352]
# number steps made: 1314
# number steps made in episode: 804
# epsilon: 0.9975280911734855
#
# episode number: 3
# episodes rewards: [-296, -352, -879]
# number steps made: 1721
# number steps made in episode: 407
# epsilon: 0.9950623544007555
#
# episode number: 4
# episodes rewards: [-296, -352, -879, -484]
# number steps made: 1874
# number steps made in episode: 153
# epsilon: 0.992602774270947
#
# episode number: 5
# episodes rewards: [-296, -352, -879, -484, -214]
# number steps made: 2001
# number steps made in episode: 127
# epsilon: 0.9901493354116764
#
# episode number: 6
# episodes rewards: [-296, -352, -879, -484, -214, -186]
# number steps made: 2493
# number steps made in episode: 492
# epsilon: 0.9877020224889427
#
# episode number: 7
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576]
# number steps made: 2880
# number steps made in episode: 387
# epsilon: 0.985260820207032
#
# episode number: 8
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459]
# number steps made: 3428
# number steps made in episode: 548
# epsilon: 0.9828257133084225
#
# episode number: 9
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625]
# number steps made: 4151
# number steps made in episode: 723
# epsilon: 0.9803966865736877
#
# episode number: 10
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788]
# number steps made: 4391
# number steps made in episode: 240
# epsilon: 0.977973724821403
#
# episode number: 11
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309]
# number steps made: 4856
# number steps made in episode: 465
# epsilon: 0.9755568129080493
#
# episode number: 12
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530]
# number steps made: 5514
# number steps made in episode: 658
# epsilon: 0.9731459357279194
#
# episode number: 13
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739]
# number steps made: 5873
# number steps made in episode: 359
# epsilon: 0.970741078213023
#
# episode number: 14
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426]
# number steps made: 6078
# number steps made in episode: 205
# epsilon: 0.968342225332993
#
# episode number: 15
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266]
# number steps made: 6523
# number steps made in episode: 445
# epsilon: 0.9659493620949908
#
# episode number: 16
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516]
# number steps made: 6935
# number steps made in episode: 412
# epsilon: 0.9635624735436136
#
# episode number: 17
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489]
# number steps made: 7063
# number steps made in episode: 128
# epsilon: 0.9611815447608
#
# episode number: 18
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185]
# number steps made: 7241
# number steps made in episode: 178
# epsilon: 0.9588065608657375
#
# episode number: 19
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243]
# number steps made: 7550
# number steps made in episode: 309
# epsilon: 0.9564375070147689
#
# episode number: 20
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374]
# number steps made: 8110
# number steps made in episode: 560
# epsilon: 0.9540743684013001
#
# episode number: 21
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643]
# number steps made: 8658
# number steps made in episode: 548
# epsilon: 0.9517171302557069
#
# episode number: 22
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629]
# number steps made: 8819
# number steps made in episode: 161
# epsilon: 0.9493657778452432
#
# episode number: 23
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226]
# number steps made: 9178
# number steps made in episode: 359
# epsilon: 0.947020296473949
#
# episode number: 24
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436]
# number steps made: 9552
# number steps made in episode: 374
# epsilon: 0.944680671482558
#
# episode number: 25
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431]
# number steps made: 9921
# number steps made in episode: 369
# epsilon: 0.9423468882484062
#
# episode number: 26
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438]
# number steps made: 10233
# number steps made in episode: 312
# epsilon: 0.940018932185341
#
# episode number: 27
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389]
# number steps made: 10647
# number steps made in episode: 414
# epsilon: 0.9376967887436294
#
# episode number: 28
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489]
# number steps made: 11082
# number steps made in episode: 435
# epsilon: 0.9353804434098673
#
# episode number: 29
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505]
# number steps made: 11388
# number steps made in episode: 306
# epsilon: 0.9330698817068888
#
# episode number: 30
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372]
# number steps made: 11642
# number steps made in episode: 254
# epsilon: 0.9307650891936757
#
# episode number: 31
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321]
# number steps made: 11835
# number steps made in episode: 193
# epsilon: 0.9284660514652673
#
# episode number: 32
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256]
# number steps made: 12457
# number steps made in episode: 622
# epsilon: 0.9261727541526704
#
# episode number: 33
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689]
# number steps made: 12958
# number steps made in episode: 501
# epsilon: 0.9238851829227694
#
# episode number: 34
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581]
# number steps made: 13268
# number steps made in episode: 310
# epsilon: 0.9216033234782365
#
# episode number: 35
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378]
# number steps made: 13713
# number steps made in episode: 445
# epsilon: 0.9193271615574428
#
# episode number: 36
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520]
# number steps made: 14066
# number steps made in episode: 353
# epsilon: 0.9170566829343688
#
# episode number: 37
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409]
# number steps made: 14338
# number steps made in episode: 272
# epsilon: 0.9147918734185159
#
# episode number: 38
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339]
# number steps made: 14650
# number steps made in episode: 312
# epsilon: 0.9125327188548171
#
# episode number: 39
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381]
# number steps made: 14975
# number steps made in episode: 325
# epsilon: 0.9102792051235491
#
# episode number: 40
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388]
# number steps made: 15240
# number steps made in episode: 265
# epsilon: 0.9080313181402437
#
# episode number: 41
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330]
# number steps made: 15593
# number steps made in episode: 353
# epsilon: 0.9057890438555999
#
# episode number: 42
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424]
# number steps made: 15922
# number steps made in episode: 329
# epsilon: 0.9035523682553963
#
# episode number: 43
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408]
# number steps made: 16329
# number steps made in episode: 407
# epsilon: 0.9013212773604029
#
# episode number: 44
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476]
# number steps made: 16549
# number steps made in episode: 220
# epsilon: 0.8990957572262945
#
# episode number: 45
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285]
# number steps made: 17095
# number steps made in episode: 546
# epsilon: 0.896875793943563
#
# episode number: 46
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631]
# number steps made: 17549
# number steps made in episode: 454
# epsilon: 0.8946613736374305
#
# episode number: 47
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533]
# number steps made: 17750
# number steps made in episode: 201
# epsilon: 0.892452482467763
#
# episode number: 48
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268]
# number steps made: 17889
# number steps made in episode: 139
# epsilon: 0.8902491066289836
#
# episode number: 49
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198]
# number steps made: 18165
# number steps made in episode: 276
# epsilon: 0.888051232349986
#
# episode number: 50
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318]
# number steps made: 18699
# number steps made in episode: 534
# epsilon: 0.8858588458940487
#
# episode number: 51
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590]
# number steps made: 19087
# number steps made in episode: 388
# epsilon: 0.8836719335587495
#
# episode number: 52
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452]
# number steps made: 19281
# number steps made in episode: 194
# epsilon: 0.881490481675879
#
# episode number: 53
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259]
# number steps made: 19665
# number steps made in episode: 384
# epsilon: 0.8793144766113556
#
# episode number: 54
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457]
# number steps made: 20262
# number steps made in episode: 597
# epsilon: 0.8771439047651411
#
# episode number: 55
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656]
# number steps made: 20738
# number steps made in episode: 476
# epsilon: 0.8749787525711541
#
# episode number: 56
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551]
# number steps made: 21042
# number steps made in episode: 304
# epsilon: 0.8728190064971862
#
# episode number: 57
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383]
# number steps made: 21294
# number steps made in episode: 252
# epsilon: 0.8706646530448178
#
# episode number: 58
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321]
# number steps made: 21634
# number steps made in episode: 340
# epsilon: 0.8685156787493323
#
# episode number: 59
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407]
# number steps made: 21704
# number steps made in episode: 70
# epsilon: 0.8663720701796339
#
# episode number: 60
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127]
# number steps made: 22063
# number steps made in episode: 359
# epsilon: 0.8642338139381617
#
# episode number: 61
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431]
# number steps made: 22396
# number steps made in episode: 333
# epsilon: 0.8621008966608072
#
# episode number: 62
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406]
# number steps made: 22730
# number steps made in episode: 334
# epsilon: 0.8599733050168307
#
# episode number: 63
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401]
# number steps made: 22928
# number steps made in episode: 198
# epsilon: 0.8578510257087774
#
# episode number: 64
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267]
# number steps made: 23080
# number steps made in episode: 152
# epsilon: 0.8557340454723947
#
# episode number: 65
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218]
# number steps made: 23242
# number steps made in episode: 162
# epsilon: 0.8536223510765493
#
# episode number: 66
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231]
# number steps made: 23540
# number steps made in episode: 298
# epsilon: 0.8515159293231441
#
# episode number: 67
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373]
# number steps made: 23754
# number steps made in episode: 214
# epsilon: 0.8494147670470367
#
# episode number: 68
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273]
# number steps made: 23898
# number steps made in episode: 144
# epsilon: 0.8473188511159557
#
# episode number: 69
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211]
# number steps made: 24466
# number steps made in episode: 568
# epsilon: 0.8452281684304199
#
# episode number: 70
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631]
# number steps made: 24605
# number steps made in episode: 139
# epsilon: 0.8431427059236555
#
# episode number: 71
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204]
# number steps made: 24740
# number steps made in episode: 135
# epsilon: 0.8410624505615153
#
# episode number: 72
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198]
# number steps made: 25257
# number steps made in episode: 517
# epsilon: 0.8389873893423964
#
# episode number: 73
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594]
# number steps made: 25589
# number steps made in episode: 332
# epsilon: 0.8369175092971592
#
# episode number: 74
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399]
# number steps made: 25722
# number steps made in episode: 133
# epsilon: 0.8348527974890472
#
# episode number: 75
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194]
# number steps made: 26233
# number steps made in episode: 511
# epsilon: 0.8327932410136044
#
# episode number: 76
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586]
# number steps made: 26512
# number steps made in episode: 279
# epsilon: 0.8307388269985964
#
# episode number: 77
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344]
# number steps made: 26965
# number steps made in episode: 453
# epsilon: 0.8286895426039287
#
# episode number: 78
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513]
# number steps made: 27472
# number steps made in episode: 507
# epsilon: 0.8266453750215673
#
# episode number: 79
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580]
# number steps made: 27906
# number steps made in episode: 434
# epsilon: 0.8246063114754583
#
# episode number: 80
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509]
# number steps made: 28093
# number steps made in episode: 187
# epsilon: 0.8225723392214475
#
# episode number: 81
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254]
# number steps made: 28399
# number steps made in episode: 306
# epsilon: 0.820543445547202
#
# episode number: 82
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387]
# number steps made: 28781
# number steps made in episode: 382
# epsilon: 0.8185196177721297
#
# episode number: 83
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455]
# number steps made: 29127
# number steps made in episode: 346
# epsilon: 0.8165008432473004
#
# episode number: 84
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419]
# number steps made: 29435
# number steps made in episode: 308
# epsilon: 0.8144871093553667
#
# episode number: 85
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381]
# number steps made: 29701
# number steps made in episode: 266
# epsilon: 0.8124784035104852
#
# episode number: 86
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337]
# number steps made: 30093
# number steps made in episode: 392
# epsilon: 0.8104747131582379
#
# episode number: 87
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471]
# number steps made: 30498
# number steps made in episode: 405
# epsilon: 0.8084760257755536
#
# episode number: 88
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468]
# number steps made: 30802
# number steps made in episode: 304
# epsilon: 0.8064823288706297
#
# episode number: 89
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371]
# number steps made: 31152
# number steps made in episode: 350
# epsilon: 0.8044936099828537
#
# episode number: 90
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417]
# number steps made: 31364
# number steps made in episode: 212
# epsilon: 0.8025098566827266
#
# episode number: 91
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271]
# number steps made: 31639
# number steps made in episode: 275
# epsilon: 0.8005310565717833
#
# episode number: 92
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271, -348]
# number steps made: 31995
# number steps made in episode: 356
# epsilon: 0.798557197282517
#
# episode number: 93
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271, -348, -427]
# number steps made: 32246
# number steps made in episode: 251
# epsilon: 0.7965882664783007
#
# episode number: 94
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271, -348, -427, -320]
# number steps made: 32527
# number steps made in episode: 281
# epsilon: 0.7946242518533103
#
# episode number: 95
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271, -348, -427, -320, -352]
# number steps made: 32788
# number steps made in episode: 261
# epsilon: 0.7926651411324482
#
# episode number: 96
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271, -348, -427, -320, -352, -328]
# number steps made: 32968
# number steps made in episode: 180
# epsilon: 0.7907109220712659
#
# episode number: 97
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271, -348, -427, -320, -352, -328, -243]
# number steps made: 33180
# number steps made in episode: 212
# epsilon: 0.7887615824558879
#
# episode number: 98
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271, -348, -427, -320, -352, -328, -243, -281]
# number steps made: 33338
# number steps made in episode: 158
# epsilon: 0.7868171101029353
#
# episode number: 99
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271, -348, -427, -320, -352, -328, -243, -281, -227]
# number steps made: 33623
# number steps made in episode: 285
# epsilon: 0.7848774928594494
#
# episode number: 100
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271, -348, -427, -320, -352, -328, -243, -281, -227, -358]
# number steps made: 33839
# number steps made in episode: 216
# epsilon: 0.7829427186028165
#
# episode number: 101
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271, -348, -427, -320, -352, -328, -243, -281, -227, -358, -289]
# number steps made: 34269
# number steps made in episode: 430
# epsilon: 0.7810127752406908
#
# episode number: 102
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271, -348, -427, -320, -352, -328, -243, -281, -227, -358, -289, -501]
# number steps made: 34552
# number steps made in episode: 283
# epsilon: 0.7790876507109202
#
# episode number: 103
# episodes rewards: [-296, -352, -879, -484, -214, -186, -576, -459, -625, -788, -309, -530, -739, -426, -266, -516, -489, -185, -243, -374, -643, -629, -226, -436, -431, -438, -389, -489, -505, -372, -321, -256, -689, -581, -378, -520, -409, -339, -381, -388, -330, -424, -408, -476, -285, -631, -533, -268, -198, -318, -590, -452, -259, -457, -656, -551, -383, -321, -407, -127, -431, -406, -401, -267, -218, -231, -373, -273, -211, -631, -204, -198, -594, -399, -194, -586, -344, -513, -580, -509, -254, -387, -455, -419, -381, -337, -471, -468, -371, -417, -271, -348, -427, -